# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pathlib import Path

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

r = requests.get(url)
data = r.json()
list(data.keys())
# Out:
# ['Response', 'Message', 'Data', 'RateLimit', 'HasWarning', 'Type']

# %%
data = data['Data']
crypto_url_df = pd.DataFrame.from_dict(data)
crypto_url_df = crypto_url_df.T
crypto_url_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# ...

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")

file_path = Path("crypto_data.csv")
crypto_df = pd.read_csv(file_path)
crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df.rename(columns = {'Unnamed: 0':'Ticker'}, inplace = True)
crypto_df.set_index("Ticker", inplace=True)
crypto_df
# Out:
#               CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# Ticker
# 42             42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365            365Coin       X11       True   PoW/PoS              NaN
# 404            404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611          SixEleven   SHA-256       True       PoW              NaN
# 808                808   SHA-256       True   PoW/PoS     0.000000e+00
# ...                ...       ...        ...       ...              ...
# XBC        BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC        DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT       Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC    OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK         SteamPunk       PoS      False       PoS              NaN
#
#        TotalCoinSupply
# Ticker
# 42                  42
# 365         2300000000
# 404          532000000
# ...

# %%
# Keep only cryptocurrencies that are trading

crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True]
#crypto_df

# %%
# Keep only cryptocurrencies with a working algorithm

crypto_df = crypto_df.loc[crypto_df['Algorithm'] != 'N/A']
#crypto_df

# %%
# Remove the "IsTrading" column

crypto_df.drop(columns = ["IsTrading"], inplace = True)
#crypto_df

# %%
# Remove rows with at least 1 null value

crypto_df.isnull().sum()
crypto_df = crypto_df.dropna()

# %%
# Remove rows with cryptocurrencies having no coins mined

crypto_df = crypto_df.loc[crypto_df['TotalCoinsMined'] != 0]
#crypto_df

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df!= "N/A"]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
CoinName = pd.DataFrame(crypto_df['CoinName'])
CoinName
# Out:
#            CoinName
# Ticker
# 42          42 Coin
# 404         404Coin
# 1337      EliteCoin
# BTC         Bitcoin
# ETH        Ethereum
# ...             ...
# ZEPH         ZEPHYR
# GAP         Gapcoin
# BDX          Beldex
# ZEN         Horizen
# XBC     BitcoinPlus
#
# [533 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns = "CoinName", inplace = True)

# %%
# Create dummy variables for text features
crypto_dummy_variables= pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
crypto_dummy_variables.head()
# Out:
#         TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# Ticker
# 42         4.199995e+01              42                                 0
# 404        1.055185e+09       532000000                                 0
# 1337       2.927942e+10    314159265359                                 0
# BTC        1.792718e+07        21000000                                 0
# ETH        1.076842e+08               0                                 0
#
#         Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# Ticker
# 42                  0                  0                   0                0
# 404                 0                  0                   0                0
# 1337                0                  0                   0                0
# BTC                 0                  0                   0                0
# ETH                 0                  0                   0                0
#
# ...

# %%
# Standardize data

crypto_scaled = StandardScaler().fit_transform(crypto_dummy_variables)
crypto_scaled
# Out:
# array([[-0.11674788, -0.15286468, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.09358885, -0.14499604, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [ 0.52587231,  4.4937636 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        ...,
#        [-0.09523411, -0.13215444, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11658774, -0.15255408, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11674507, -0.15284989, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ]])

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(crypto_scaled)

# %%
# Create a DataFrame with the principal components data
pca_df = pd.DataFrame(
         data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"]
)
pca_df.head()
# Out:
#        PC 1      PC 2      PC 3
# 0 -0.330647  1.109282 -0.066609
# 1 -0.313967  1.109665 -0.066603
# 2  2.298921  1.798485 -0.073654
# 3 -0.148326 -1.306752  0.035779
# 4 -0.154599 -1.994291  0.018185

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pca_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
km = KMeans(n_clusters=4, random_state=0)
# Fit the model
km.fit(pca_df)
# Predict clusters
predictions = km.predict(pca_df)
# Create a new DataFrame including predicted clusters and cryptocurrencies features
pca_df['class'] = km.labels_
pca_df.index = crypto_df.index

# %%
crypto_df.head()
clustered_df = pd.concat([crypto_df, pca_df,CoinName], axis=1, )
clustered_df.head()
# Out:
#        Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1  \
# Ticker
# 42        Scrypt   PoW/PoS     4.199995e+01              42 -0.330647
# 404       Scrypt   PoW/PoS     1.055185e+09       532000000 -0.313967
# 1337         X13   PoW/PoS     2.927942e+10    314159265359  2.298921
# BTC      SHA-256       PoW     1.792718e+07        21000000 -0.148326
# ETH       Ethash       PoW     1.076842e+08               0 -0.154599
#
#             PC 2      PC 3  class   CoinName
# Ticker
# 42      1.109282 -0.066609      0    42 Coin
# 404     1.109665 -0.066603      0    404Coin
# 1337    1.798485 -0.073654      0  EliteCoin
# BTC    -1.306752  0.035779      3    Bitcoin
# ETH    -1.994291  0.018185      3   Ethereum

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
clustered_df["TotalCoinSupply"]= clustered_df["TotalCoinSupply"].astype(float)/100000000
clustered_df["TotalCoinsMined"]= clustered_df["TotalCoinsMined"].astype(float)/100000000

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
clustered_df.hvplot(
    kind="scatter",
    x= "TotalCoinsMined",
    y= "TotalCoinSupply",
    hover_cols=["CoinName"],
    by= "class")
# Out:
# :NdOverlay   [class]
#    :Scatter   [TotalCoinsMined]   (TotalCoinSupply,CoinName)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
columns = ['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 'TotalCoinsMined', 'class']
table = clustered_df.hvplot.table(columns)
table
# Out:
# :Table   [CoinName,Algorithm,ProofType,TotalCoinSupply,TotalCoinsMined,class]

# %%
# Print the total number of tradable cryptocurrencies
clustered_df.hvplot(
    kind="scatter",
    x= "TotalCoinsMined",
    y= "TotalCoinSupply",
    hover_cols=["CoinName"],
    by= "class")
# Out:
# :NdOverlay   [class]
#    :Scatter   [TotalCoinsMined]   (TotalCoinSupply,CoinName)
